# %% [markdown]
# # **Import các thư viện :**

# %%
# !pip install --upgrade tensorflow==2.16.1
# !pip install scikit-image
# Out:
# Collecting tensorflow==2.16.1
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (16.0.6)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.1)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.51.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.1)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (0.35.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.16.1) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.16.1) (0.42.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (13.7.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.1) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1) (3.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.16.1) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.1) (0.1.2)
# Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.8 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 66.2 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 92.3 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# tensorflow-decision-forests 1.8.1 requires tensorflow~=2.15.0, but you have tensorflow 2.16.1 which is incompatible.
# tensorflow-text 2.15.0 requires tensorflow<2.16,>=2.15.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.16.1 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
# Successfully installed ml-dtypes-0.3.2 tensorboard-2.16.2 tensorflow-2.16.1
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image) (3.1.1)

# %%
#Import các thư viện xử lý ảnh :
import os
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tifffile as tiff
from glob import glob
import seaborn as sns 
import albumentations as albu
from skimage.io import imread
from tqdm import tqdm
import gc


#Tensorflow Imports :
import tensorflow as tf
import tensorflow.keras as k
import keras
from tensorflow import reduce_sum
from tensorflow.keras.utils import Sequence , normalize , img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, Layer,
                                    Conv2DTranspose, MaxPool2D, MaxPooling2D, Dropout,
                                    Flatten, Activation, Concatenate, UpSampling2D,
                                    BatchNormalization , MaxPooling2D,
                                    Add, Multiply, Lambda, GlobalAveragePooling2D, 
                                    GlobalMaxPooling2D, Reshape, Dense, LeakyReLU)

from tensorflow.keras.losses import binary_crossentropy
from keras.losses import BinaryFocalCrossentropy
from tensorflow.keras.optimizers import AdamW, RMSprop, Nadam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
import tensorflow.keras.backend as K
from keras.callbacks import CSVLogger


#Sklearn Import :
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, jaccard_score

# %% [markdown]
# # **Xây dựng các thành phần của mô hình :**

# %%
kernel_initializer = 'he_uniform'

#Conv :
def Deep_Block(x, num_filters, expansion=8):
    #x shape :
    x_shape = K.int_shape(x)
    
    #Shortcut :
    if x_shape[3] == num_filters :
        shortcut = x
    else :
        shortcut = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
        shortcut = BatchNormalization()(shortcut)
    
    #State 1 :
    x1 = Conv2D(num_filters * expansion, (1, 1), kernel_initializer=kernel_initializer, 
               padding='same', use_bias=False)(x)
    
    x1 = BatchNormalization(axis=-1)(x1)
    
    x1 = Activation('relu')(x1)    
    
    x1 = Residual_Block(x1, num_filters * expansion)
    
    x1 = Conv2D(num_filters, (1, 1), kernel_initializer=kernel_initializer, 
               padding='same', use_bias=False)(x1)
    x1_1 = BatchNormalization(axis=-1)(x1)
    
    x1 = Add()([x1_1, shortcut])
        
    #State 2 :
    x2 = Conv2D(num_filters // expansion, (1, 1), kernel_initializer=kernel_initializer, 
               padding='same', use_bias=False)(x1)
    x2 = BatchNormalization(axis=-1)(x2)
    x2 = Activation('relu')(x2)
    
    x2 = Residual_Block(x2, num_filters // expansion)

    x2 = Conv2D(num_filters, (1, 1), kernel_initializer=kernel_initializer, 
               padding='same', use_bias=False)(x2)
    x2 = BatchNormalization(axis=-1)(x2)
    
    output = Add()([x2, x1_1, shortcut])
    
    output = Activation('relu')(output)
    
    return output

#Bottle Neck Residual Block :
def Bottleneck_Residual_Block(x, num_filters, expansion=4):
    #x shape :
    x_shape = K.int_shape(x)
    
    #Shortcut :
    if x_shape[3] == num_filters :
        shortcut = x
    else :
        shortcut = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
        shortcut = BatchNormalization()(shortcut)
    
    #Residual :
    x = Conv2D(num_filters//expansion, (1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(num_filters//expansion, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    
    #Add
    output = Add()([x, shortcut])
    
    #Activation :
    output = Activation('relu')(output)

    return output
    
#Residual Block :
def Residual_Block(x, num_filters):
    #x shape :
    x_shape = K.int_shape(x)
    
    #Shortcut :
    if x_shape[3] == num_filters :
        shortcut = x
    else :
        shortcut = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
        shortcut = BatchNormalization()(shortcut)
    
    #Residual :
    x = Conv2D(num_filters, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(num_filters, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    
    #Add
    output = Add()([x, shortcut])
    
    #Activation :
    output = Activation('relu')(output)
    
    return output

def Inverted_Residual_Block(x, num_filters, expansion=4):
    #x shape :
    x_shape = K.int_shape(x)
    
    #Shortcut :
    if x_shape[3] == num_filters :
        shortcut = x
    else :
        shortcut = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
        shortcut = BatchNormalization()(shortcut)
    
    #Residual :
    x = Conv2D(num_filters*expansion, (1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(num_filters*expansion, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(num_filters, (1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    
    #Add
    output = Add()([x, shortcut])
    
    #Activation :
    output = Activation('relu')(output)
    
    return output

# %%
def DCGC_Block(x, num_filters, expansion=2, repeat=5): 
    #Shortcut :
    shortcut = Conv2D(num_filters, (1, 1), kernel_initializer=kernel_initializer, 
               padding='same', use_bias=False)(x)
    shortcut = BatchNormalization(axis=-1)(shortcut)
    shortcut = Activation('relu')(shortcut)    
    
    temp = b = x 
    i = x 
    for _ in range(repeat):
        b = Bottleneck_Residual_Block(i, num_filters, expansion=expansion)
        i = Inverted_Residual_Block(temp, num_filters, expansion=expansion)
        temp = b
        
    output = Add()([shortcut, b, i])
    
    #MaxPooling 2D :
    output = MaxPooling2D((2,2))(output)   
    
    return output


def Scale_Down(x, pre_dcgc, num_filters, first_sc=False):
    if first_sc :
        deep = Deep_Block(x, num_filters, expansion=2)    
    else :
        add = Add()([x, pre_dcgc])
        deep = Deep_Block(add, num_filters, expansion=2)    
    
    #DownSample :
    down = MaxPooling2D((2,2))(deep)

    return deep, down
    
def Scale_Up(x, s, num_filters):
    #Reisize :
    res = UpSampling2D((2,2), interpolation='bilinear')(x)
    
    add = Add()([s, res])
    
    deep = Deep_Block(add, num_filters, expansion=2)    

    return deep

# %% [markdown]
# # **Xây dựng mô hình :**

# %%
def DCGC_Net(input_shape=(256, 256, 3), num_classes=1, start_filters=32):
    input_layer = Input(shape=input_shape)
    
    #Deep Conv : 
    dcgc_1 = DCGC_Block(input_layer, start_filters, 4, 3)
    dcgc_2 = DCGC_Block(dcgc_1, start_filters * 2, 4, 4)    
    dcgc_3 = DCGC_Block(dcgc_2, start_filters * 4, 4, 5)    
    dcgc_4 = DCGC_Block(dcgc_3, start_filters * 8, 4, 6)
    dcgc_5 = DCGC_Block(dcgc_4, start_filters * 16, 4, 7)    
    
    #Scale Down State :
    #State 1 : 
    sd_1, down_1 = Scale_Down(input_layer, None,start_filters, first_sc=True) 
    
    #State 2 :     
    sd_2, down_2 = Scale_Down(down_1, dcgc_1, start_filters*2) 
    
    #State 3 :
    sd_3, down_3 = Scale_Down(down_2, dcgc_2, start_filters*4) 
    
    #State 4 :     
    sd_4, down_4 = Scale_Down(down_3, dcgc_3, start_filters*8) 
    
    #State 5 :
    sd_5, down_5 = Scale_Down(down_4, dcgc_4, start_filters*16) 
    
    #Brigde :
    brigde_1 = Add()([down_5, dcgc_5])
    
    for _ in range(2):
        brigde_1 = Residual_Block(brigde_1, start_filters*32)
    
    brigde_2 = brigde_1
    for _ in range(2):
        brigde_2 = Residual_Block(brigde_2, start_filters*16)
    
    #Scale Up State :
    #State 1 :  
    su_1 = Scale_Up(brigde_2, sd_5, start_filters*8)
    
    #State 2 : 
    su_2 = Scale_Up(su_1, sd_4, start_filters*4)
    
    #State 3: 
    su_3 = Scale_Up(su_2, sd_3, start_filters*2)

    #State 4: 
    su_4 = Scale_Up(su_3, sd_2, start_filters)
    
    #State 5: 
    su_5 = Scale_Up(su_4, sd_1, start_filters)
    
    #Output : 
    outputs = Conv2D(num_classes, (1, 1), activation='sigmoid')(su_5)

    #Model :
    model = Model(inputs=input_layer, outputs=outputs, name='DCGC_Net')
    
    return model

# %% [markdown]
# # **Xây dựng các hàm Loss và Metrics :**

# %%
def Dice_Coef(y_true, y_pred, smooth=1e-6):
    y_true = K.cast(y_true, tf.float32)
    y_pred = K.cast(y_pred, tf.float32)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)
    return ((2. * intersection + smooth) / (union + smooth))

def Dice_Loss(y_true, y_pred):
    return 1 - Dice_Coef(y_true, y_pred)

# %% [markdown]
# # **Tiến hành xây dựng các hàm đọc và xử lý dữ liệu ảnh :**

# %%
def load_data(img_height, img_width, path):
    IMAGES_PATH = path + '/images/'
    MASKS_PATH = path + '/masks/'

    ids = glob(IMAGES_PATH + "*.jpg")

    num_images = len(ids)
    X = np.zeros((num_images, img_height, img_width, 3), dtype=np.float32)
    Y = np.zeros((num_images, img_height, img_width), dtype=np.float32)

    for n, id_ in tqdm(enumerate(ids), total=num_images):
        image_path = id_
        mask_path = image_path.replace("images", "masks")

        image = imread(image_path)
        mask_ = imread(mask_path)

        #Resize image
        pillow_image = Image.fromarray(image)
        pillow_image = pillow_image.resize((img_width, img_height))
        image = np.array(pillow_image)

        X[n] = image / 255.0  #Normalize image

        #Resize mask
        pillow_mask = Image.fromarray(mask_)
        pillow_mask = pillow_mask.resize((img_width, img_height), resample=Image.LANCZOS)
        mask_ = np.array(pillow_mask)

        if mask_.ndim == 3 and mask_.shape[2] > 1:
            mask = (np.mean(mask_, axis=-1) >= 127).astype(np.float32)
        else:
            mask = (mask_ >= 127).astype(np.float32)

        Y[n] = mask

    Y = np.expand_dims(Y, axis=-1)

    return X, Y

#Defining the augmentations :
aug_train = albu.Compose([
    albu.HorizontalFlip(),
    albu.VerticalFlip(),
    albu.ColorJitter(brightness=(0.6,1.6), contrast=0.2, saturation=0.1, hue=0.01, always_apply=True),
    albu.Affine(scale=(0.5,1.5), translate_percent=(-0.125,0.125), rotate=(-180,180), shear=(-22.5,22), always_apply=True),
])

def augment_images(x_train, y_train):
    x_train_out = []
    y_train_out = []

    for i in range (len(x_train)):
        aug = aug_train(image=x_train[i], mask=y_train[i])
        x_train_out.append(aug['image'])  
        y_train_out.append(aug['mask'])

    return np.array(x_train_out), np.array(y_train_out)

# %%
test = 0.15
seed = 42
img_size = 256

#Load Data : 
X, Y = load_data(img_size, img_size, '/kaggle/input/kvasir-segmentation/Kvasir-SEG')
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=test, shuffle= True, random_state = seed)
# Out:
# 100%|██████████| 1000/1000 [00:29<00:00, 34.30it/s]

# %% [markdown]
# # **Khởi tạo mô hình :**

# %%
model = DCGC_Net(input_shape=(256, 256, 3), num_classes=1, start_filters = 8)
model.summary()
# Out:
# Model: "DCGC_Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │          6 │ input_layer[0][0] │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 256, 256,  │         96 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │         36 │ activation_1[0][… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 256, 256,  │      9,216 │ activation_4[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 256, 256,  │         16 │ activation_2[0][… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │         24 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │        256 │ activation_5[0][… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │         24 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ add[0][0]         │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256, 256,  │          0 │ add_1[0][0]       │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │        256 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 256, 256,  │         16 │ activation_6[0][… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_10[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         36 │ activation_7[0][… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │        256 │ activation_11[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 256, 256,  │         16 │ activation_8[0][… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 256, 256,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 256, 256,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 256, 256,  │         16 │ activation_12[0]… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        256 │ activation_9[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │         36 │ activation_13[0]… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_16[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          8 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │         16 │ activation_14[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │        256 │ activation_17[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         24 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         32 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 256, 256,  │          0 │ add_4[0][0]       │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ add_5[0][0]       │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 8)                │            │ activation_15[0]… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ add_6[0][0]       │
# │ (MaxPooling2D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │        512 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │         32 │ max_pooling2d[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_23[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │        144 │ activation_20[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_24[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │        128 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_21[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │        128 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 128, 128,  │          0 │ add_8[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 128, 128,  │          0 │ add_7[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_25[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_22[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │        144 │ activation_26[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_29[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_27[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_30[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 128, 128,  │          0 │ add_9[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128, 128,  │          0 │ add_10[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_28[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_31[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_35[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │        144 │ activation_32[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_36[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_33[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 128, 128,  │          0 │ add_12[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 128, 128,  │          0 │ add_11[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_37[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_34[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 128, 128,  │        144 │ activation_38[0]… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_41[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 128, 128,  │         64 │ activation_39[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 128, 128,  │      1,024 │ activation_42[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │        128 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_34[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 128, 128,  │          0 │ add_13[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 128, 128,  │          0 │ add_14[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 128, 128,  │          0 │ activation_19[0]… │
# │                     │ 16)               │            │ activation_40[0]… │
# │                     │                   │            │ activation_43[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ add_15[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 64, 8) │        128 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 64, 64,    │      2,048 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 8) │         32 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 64, 64, 8) │        576 │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 64, 64,    │    147,456 │ activation_48[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 8) │         32 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │        256 │ activation_46[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 64, 64,    │        512 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 64, 64,    │      4,096 │ activation_49[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │        512 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 64, 64,    │          0 │ add_16[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 64, 64,    │          0 │ add_17[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 64, 64,    │      4,096 │ activation_47[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 64, 64, 8) │        256 │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 8) │         32 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 64, 64,    │    147,456 │ activation_54[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 64, 64, 8) │        576 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 8) │         32 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 64, 64,    │      4,096 │ activation_55[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 64, 64,    │        256 │ activation_52[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_47[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 64, 64,    │          0 │ add_19[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 64, 64,    │          0 │ add_18[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 64, 64, 8) │        256 │ activation_56[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 64, 64,    │      4,096 │ activation_53[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 8) │         32 │ conv2d_63[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_66[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ...
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_97 (Add)        │ (None, 64, 64, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_215[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_217      │ (None, 64, 64, 8) │          0 │ add_97[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_246 (Conv2D) │ (None, 64, 64,    │        128 │ activation_217[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_246[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_98 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_218      │ (None, 64, 64,    │          0 │ add_98[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ activation_218[0… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_99 (Add)        │ (None, 128, 128,  │          0 │ activation_168[0… │
# │                     │ 16)               │            │ up_sampling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_248 (Conv2D) │ (None, 128, 128,  │        256 │ add_99[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_248[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_219      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_249 (Conv2D) │ (None, 128, 128,  │      2,304 │ activation_219[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_249[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_220      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_250 (Conv2D) │ (None, 128, 128,  │      2,304 │ activation_220[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_250[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_100 (Add)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_219[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_221      │ (None, 128, 128,  │          0 │ add_100[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_251 (Conv2D) │ (None, 128, 128,  │        128 │ activation_221[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_247 (Conv2D) │ (None, 128, 128,  │        128 │ add_99[0][0]      │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         32 │ conv2d_251[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         32 │ conv2d_247[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_101 (Add)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_252 (Conv2D) │ (None, 128, 128,  │         32 │ add_101[0][0]     │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_252[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_222      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_253 (Conv2D) │ (None, 128, 128,  │        144 │ activation_222[0… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_253[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_223      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_254 (Conv2D) │ (None, 128, 128,  │        144 │ activation_223[0… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         16 │ conv2d_254[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 4)                │            │ activation_222[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_224      │ (None, 128, 128,  │          0 │ add_102[0][0]     │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_255 (Conv2D) │ (None, 128, 128,  │         32 │ activation_224[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         32 │ conv2d_255[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_225      │ (None, 128, 128,  │          0 │ add_103[0][0]     │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 256, 256,  │          0 │ activation_225[0… │
# │ (UpSampling2D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_104 (Add)       │ (None, 256, 256,  │          0 │ activation_161[0… │
# │                     │ 8)                │            │ up_sampling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_256 (Conv2D) │ (None, 256, 256,  │        128 │ add_104[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_256[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_226      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_257 (Conv2D) │ (None, 256, 256,  │      2,304 │ activation_226[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_257[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_227      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_258 (Conv2D) │ (None, 256, 256,  │      2,304 │ activation_227[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_258[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_105 (Add)       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_226[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_228      │ (None, 256, 256,  │          0 │ add_105[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_259 (Conv2D) │ (None, 256, 256,  │        128 │ activation_228[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_259[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_106 (Add)       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ add_104[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_260 (Conv2D) │ (None, 256, 256,  │         32 │ add_106[0][0]     │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         16 │ conv2d_260[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_229      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_261 (Conv2D) │ (None, 256, 256,  │        144 │ activation_229[0… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         16 │ conv2d_261[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_230      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_262 (Conv2D) │ (None, 256, 256,  │        144 │ activation_230[0… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         16 │ conv2d_262[0][0]  │
# │ (BatchNormalizatio… │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_107 (Add)       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 4)                │            │ activation_229[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_231      │ (None, 256, 256,  │          0 │ add_107[0][0]     │
# │ (Activation)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_263 (Conv2D) │ (None, 256, 256,  │         32 │ activation_231[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_263[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_108 (Add)       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │ batch_normalizat… │
# │                     │                   │            │ add_104[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_232      │ (None, 256, 256,  │          0 │ add_108[0][0]     │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_264 (Conv2D) │ (None, 256, 256,  │          9 │ activation_232[0… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,468,059 (104.78 MB)
#  Trainable params: 27,422,763 (104.61 MB)
#  Non-trainable params: 45,296 (176.94 KB)

# %% [markdown]
# # **Compile cho model đã khởi tạo :**

# %%
#Tạo optimizer:
EPOCHS = 600
learning_rate = 3e-4

#Tạo optimizer :
optimizer = RMSprop(learning_rate = learning_rate
                 )

#Compile mô hình :
model.compile(loss=Dice_Loss,
              optimizer=optimizer,
              metrics=[Dice_Coef])

# %% [markdown]
# # **Tiến hành training mô hình :**

# %%
model_path = 'DCGC_Deep_Net.keras'

# %%
step = 0
min_loss_for_saving = 0.12
metric = -1
epoch_save_weight = -1
for epoch in range(0, EPOCHS):
    
    print(f'Training, epoch {epoch+1}/{EPOCHS}')
    print('='*50)
            
    image_augmented, mask_augmented = augment_images(x_train, y_train)
        
    model.fit(x=image_augmented, y=mask_augmented, epochs=1, batch_size=8, 
              validation_data=None, verbose=1)
    
    prediction = model.predict(x_test, batch_size=8, verbose=0)
    loss = Dice_Loss(y_test, prediction)
    
    loss = loss.numpy()
    metric_t = (1 - loss) * 100 
    print(f"Metric Test : {metric_t:.4f}%")
    print("Loss Test : " + str(loss))
    print('='*50)

    if min_loss_for_saving > loss:
        min_loss_for_saving = loss
        epoch_save_weight = epoch+1
        metric = (1 - min_loss_for_saving) * 100
        print("Saved model with min loss: ", loss)
        model.save(model_path)
        print('='*50)
    
    if epoch_save_weight > 0 :
        print(f'Save model from epoch {epoch_save_weight} with metric {metric:.4f}%')
        print('='*50)

    del image_augmented
    del mask_augmented

    gc.collect()
# Out:
# Training, epoch 1/600
# ==================================================
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724042420.985065      79 service.cc:145] XLA service 0x79a37c0052a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724042420.985130      79 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1724042519.687181      79 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - dice__coef: 0.3263 - loss: 0.6737
# Metric Test : 33.6575%
# Loss Test : 0.6634252
# ==================================================
# Training, epoch 2/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.4429 - loss: 0.5571
# Metric Test : 26.0447%
# Loss Test : 0.7395531
# ==================================================
# Training, epoch 3/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.4557 - loss: 0.5443
# Metric Test : 33.8835%
# Loss Test : 0.66116536
# ==================================================
# Training, epoch 4/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.4654 - loss: 0.5346
# Metric Test : 46.3721%
# Loss Test : 0.5362791
# ==================================================
# Training, epoch 5/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.4730 - loss: 0.5269
# Metric Test : 48.5679%
# Loss Test : 0.51432073
# ==================================================
# Training, epoch 6/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.4922 - loss: 0.5077
# Metric Test : 48.7414%
# Loss Test : 0.51258564
# ==================================================
# Training, epoch 7/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.5032 - loss: 0.4968
# Metric Test : 51.6728%
# Loss Test : 0.48327214
# ==================================================
# Training, epoch 8/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.5127 - loss: 0.4873
# Metric Test : 44.1198%
# Loss Test : 0.5588018
# ==================================================
# Training, epoch 9/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.5114 - loss: 0.4886
# Metric Test : 51.4173%
# Loss Test : 0.48582667
# ==================================================
# Training, epoch 10/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.5065 - loss: 0.4935
# Metric Test : 50.6793%
# Loss Test : 0.49320704
# ==================================================
# Training, epoch 11/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.5319 - loss: 0.4680
# Metric Test : 51.6264%
# Loss Test : 0.48373586
# ==================================================
# Training, epoch 12/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.5344 - loss: 0.4656
# Metric Test : 55.5106%
# Loss Test : 0.44489384
# ==================================================
# Training, epoch 13/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.5473 - loss: 0.4527
# Metric Test : 57.1246%
# Loss Test : 0.42875385
# ==================================================
# Training, epoch 14/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.5670 - loss: 0.4330
# Metric Test : 37.9598%
# Loss Test : 0.6204022
# ==================================================
# Training, epoch 15/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.5396 - loss: 0.4604
# Metric Test : 56.5068%
# Loss Test : 0.43493193
# ==================================================
# Training, epoch 16/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.5427 - loss: 0.4573
# Metric Test : 55.3386%
# Loss Test : 0.44661438
# ==================================================
# Training, epoch 17/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.5565 - loss: 0.4435
# Metric Test : 56.8072%
# Loss Test : 0.43192792
# ==================================================
# Training, epoch 18/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.5847 - loss: 0.4153
# Metric Test : 61.5999%
# Loss Test : 0.3840009
# ==================================================
# Training, epoch 19/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.5788 - loss: 0.4212
# Metric Test : 59.2601%
# Loss Test : 0.40739936
# ==================================================
# Training, epoch 20/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.5643 - loss: 0.4357
# Metric Test : 59.1811%
# Loss Test : 0.408189
# ==================================================
# Training, epoch 21/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 228ms/step - dice__coef: 0.5933 - loss: 0.4067
# Metric Test : 62.2315%
# Loss Test : 0.37768537
# ==================================================
# Training, epoch 22/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 228ms/step - dice__coef: 0.6026 - loss: 0.3974
# Metric Test : 60.5289%
# Loss Test : 0.39471078
# ==================================================
# Training, epoch 23/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 228ms/step - dice__coef: 0.5890 - loss: 0.4110
# Metric Test : 59.1823%
# Loss Test : 0.40817666
# ==================================================
# Training, epoch 24/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 228ms/step - dice__coef: 0.5999 - loss: 0.4001
# Metric Test : 52.0389%
# Loss Test : 0.47961068
# ==================================================
# Training, epoch 25/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.6126 - loss: 0.3875
# Metric Test : 62.2947%
# Loss Test : 0.3770529
# ==================================================
# Training, epoch 26/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.5905 - loss: 0.4096
# Metric Test : 62.0269%
# Loss Test : 0.37973088
# ==================================================
# Training, epoch 27/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6144 - loss: 0.3856
# Metric Test : 63.9431%
# Loss Test : 0.36056918
# ==================================================
# Training, epoch 28/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6038 - loss: 0.3962
# Metric Test : 49.5861%
# Loss Test : 0.50413895
# ==================================================
# Training, epoch 29/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6199 - loss: 0.3801
# Metric Test : 63.9144%
# Loss Test : 0.360856
# ==================================================
# Training, epoch 30/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6299 - loss: 0.3701
# Metric Test : 64.7693%
# Loss Test : 0.3523072
# ==================================================
# Training, epoch 31/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6101 - loss: 0.3899
# Metric Test : 59.0141%
# Loss Test : 0.40985942
# ==================================================
# Training, epoch 32/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.6243 - loss: 0.3757
# Metric Test : 68.2766%
# Loss Test : 0.31723434
# ==================================================
# Training, epoch 33/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.6164 - loss: 0.3837
# Metric Test : 61.1031%
# Loss Test : 0.38896948
# ==================================================
# Training, epoch 34/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.6383 - loss: 0.3617
# Metric Test : 64.1301%
# Loss Test : 0.3586989
# ==================================================
# Training, epoch 35/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6163 - loss: 0.3836
# Metric Test : 63.2508%
# Loss Test : 0.36749238
# ==================================================
# Training, epoch 36/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6535 - loss: 0.3465
# Metric Test : 60.5286%
# Loss Test : 0.394714
# ==================================================
# Training, epoch 37/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6312 - loss: 0.3688
# Metric Test : 63.8669%
# Loss Test : 0.3613308
# ==================================================
# Training, epoch 38/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6479 - loss: 0.3521
# Metric Test : 66.2515%
# Loss Test : 0.33748454
# ==================================================
# Training, epoch 39/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6443 - loss: 0.3557
# Metric Test : 68.5982%
# Loss Test : 0.3140183
# ==================================================
# Training, epoch 40/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6547 - loss: 0.3453
# Metric Test : 69.5435%
# Loss Test : 0.3045649
# ==================================================
# Training, epoch 41/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6470 - loss: 0.3529
# Metric Test : 72.0016%
# Loss Test : 0.27998394
# ==================================================
# Training, epoch 42/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6521 - loss: 0.3479
# Metric Test : 65.2724%
# Loss Test : 0.34727633
# ==================================================
# Training, epoch 43/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6757 - loss: 0.3243
# Metric Test : 71.4341%
# Loss Test : 0.28565872
# ==================================================
# Training, epoch 44/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6682 - loss: 0.3319
# Metric Test : 68.9688%
# Loss Test : 0.31031162
# ==================================================
# Training, epoch 45/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.6598 - loss: 0.3402
# Metric Test : 68.4958%
# Loss Test : 0.31504178
# ==================================================
# Training, epoch 46/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.6475 - loss: 0.3525
# Metric Test : 66.9949%
# Loss Test : 0.33005142
# ==================================================
# Training, epoch 47/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6763 - loss: 0.3237
# Metric Test : 73.4139%
# Loss Test : 0.26586115
# ==================================================
# Training, epoch 48/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7056 - loss: 0.2943
# Metric Test : 73.9871%
# Loss Test : 0.26012945
# ==================================================
# Training, epoch 49/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6732 - loss: 0.3268
# Metric Test : 71.2631%
# Loss Test : 0.2873695
# ==================================================
# Training, epoch 50/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.6827 - loss: 0.3174
# Metric Test : 75.0088%
# Loss Test : 0.24991238
# ==================================================
# Training, epoch 51/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.6789 - loss: 0.3211
# Metric Test : 64.4328%
# Loss Test : 0.35567248
# ==================================================
# Training, epoch 52/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.6929 - loss: 0.3071
# Metric Test : 68.4156%
# Loss Test : 0.31584382
# ==================================================
# Training, epoch 53/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.6949 - loss: 0.3051
# Metric Test : 73.6808%
# Loss Test : 0.26319218
# ==================================================
# Training, epoch 54/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7152 - loss: 0.2848
# Metric Test : 66.2183%
# Loss Test : 0.33781654
# ==================================================
# Training, epoch 55/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7023 - loss: 0.2976
# Metric Test : 73.8292%
# Loss Test : 0.26170844
# ==================================================
# Training, epoch 56/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7102 - loss: 0.2898
# Metric Test : 73.7376%
# Loss Test : 0.2626242
# ==================================================
# Training, epoch 57/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7080 - loss: 0.2920
# Metric Test : 77.2364%
# Loss Test : 0.22763628
# ==================================================
# Training, epoch 58/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7154 - loss: 0.2846
# Metric Test : 69.4837%
# Loss Test : 0.3051628
# ==================================================
# Training, epoch 59/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7175 - loss: 0.2825
# Metric Test : 76.3501%
# Loss Test : 0.23649895
# ==================================================
# Training, epoch 60/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7149 - loss: 0.2851
# Metric Test : 77.9434%
# Loss Test : 0.2205661
# ==================================================
# Training, epoch 61/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.6982 - loss: 0.3018
# Metric Test : 72.0527%
# Loss Test : 0.27947253
# ==================================================
# Training, epoch 62/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7306 - loss: 0.2694
# Metric Test : 70.7794%
# Loss Test : 0.29220635
# ==================================================
# Training, epoch 63/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7217 - loss: 0.2783
# Metric Test : 77.5397%
# Loss Test : 0.22460282
# ==================================================
# Training, epoch 64/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7418 - loss: 0.2581
# Metric Test : 75.8461%
# Loss Test : 0.24153888
# ==================================================
# Training, epoch 65/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7391 - loss: 0.2609
# Metric Test : 75.6245%
# Loss Test : 0.2437554
# ==================================================
# Training, epoch 66/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7151 - loss: 0.2849
# Metric Test : 76.9747%
# Loss Test : 0.23025292
# ==================================================
# Training, epoch 67/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7408 - loss: 0.2592
# Metric Test : 79.3918%
# Loss Test : 0.20608163
# ==================================================
# Training, epoch 68/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7235 - loss: 0.2765
# Metric Test : 78.4857%
# Loss Test : 0.21514332
# ==================================================
# Training, epoch 69/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7330 - loss: 0.2670
# Metric Test : 77.2741%
# Loss Test : 0.22725904
# ==================================================
# Training, epoch 70/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7096 - loss: 0.2904
# Metric Test : 67.8629%
# Loss Test : 0.32137114
# ==================================================
# Training, epoch 71/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7639 - loss: 0.2361
# Metric Test : 78.0566%
# Loss Test : 0.2194342
# ==================================================
# Training, epoch 72/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7212 - loss: 0.2788
# Metric Test : 75.5468%
# Loss Test : 0.24453229
# ==================================================
# Training, epoch 73/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7459 - loss: 0.2541
# Metric Test : 70.9320%
# Loss Test : 0.2906797
# ==================================================
# Training, epoch 74/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7151 - loss: 0.2849
# Metric Test : 72.9209%
# Loss Test : 0.27079135
# ==================================================
# Training, epoch 75/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7188 - loss: 0.2812
# Metric Test : 78.9075%
# Loss Test : 0.21092498
# ==================================================
# Training, epoch 76/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7469 - loss: 0.2531
# Metric Test : 76.3347%
# Loss Test : 0.23665321
# ==================================================
# Training, epoch 77/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7467 - loss: 0.2533
# Metric Test : 78.0792%
# Loss Test : 0.21920794
# ==================================================
# Training, epoch 78/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7483 - loss: 0.2517
# Metric Test : 74.4962%
# Loss Test : 0.25503802
# ==================================================
# Training, epoch 79/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7329 - loss: 0.2671
# Metric Test : 80.0615%
# Loss Test : 0.19938529
# ==================================================
# Training, epoch 80/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7604 - loss: 0.2396
# Metric Test : 80.1183%
# Loss Test : 0.19881672
# ==================================================
# Training, epoch 81/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7301 - loss: 0.2699
# Metric Test : 78.8974%
# Loss Test : 0.21102583
# ==================================================
# Training, epoch 82/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7565 - loss: 0.2435
# Metric Test : 78.7765%
# Loss Test : 0.21223545
# ==================================================
# Training, epoch 83/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7619 - loss: 0.2381
# Metric Test : 80.5103%
# Loss Test : 0.19489652
# ==================================================
# Training, epoch 84/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7474 - loss: 0.2526
# Metric Test : 79.6826%
# Loss Test : 0.20317364
# ==================================================
# Training, epoch 85/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7605 - loss: 0.2395
# Metric Test : 80.4368%
# Loss Test : 0.1956318
# ==================================================
# Training, epoch 86/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7508 - loss: 0.2492
# Metric Test : 80.2001%
# Loss Test : 0.19799912
# ==================================================
# Training, epoch 87/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7669 - loss: 0.2330
# Metric Test : 79.1296%
# Loss Test : 0.20870441
# ==================================================
# Training, epoch 88/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7496 - loss: 0.2504
# Metric Test : 81.1336%
# Loss Test : 0.18866408
# ==================================================
# Training, epoch 89/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7629 - loss: 0.2371
# Metric Test : 82.1084%
# Loss Test : 0.1789164
# ==================================================
# Training, epoch 90/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7719 - loss: 0.2281
# Metric Test : 79.5791%
# Loss Test : 0.20420921
# ==================================================
# Training, epoch 91/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7691 - loss: 0.2309
# Metric Test : 79.5586%
# Loss Test : 0.20441443
# ==================================================
# Training, epoch 92/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7781 - loss: 0.2219
# Metric Test : 78.8313%
# Loss Test : 0.21168655
# ==================================================
# Training, epoch 93/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7469 - loss: 0.2531
# Metric Test : 77.4578%
# Loss Test : 0.2254219
# ==================================================
# Training, epoch 94/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7759 - loss: 0.2241
# Metric Test : 82.0026%
# Loss Test : 0.17997438
# ==================================================
# Training, epoch 95/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7647 - loss: 0.2353
# Metric Test : 82.3144%
# Loss Test : 0.17685598
# ==================================================
# Training, epoch 96/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7573 - loss: 0.2427
# Metric Test : 81.7630%
# Loss Test : 0.18236983
# ==================================================
# Training, epoch 97/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7722 - loss: 0.2277
# Metric Test : 82.2266%
# Loss Test : 0.17773426
# ==================================================
# Training, epoch 98/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7806 - loss: 0.2194
# Metric Test : 83.6458%
# Loss Test : 0.16354203
# ==================================================
# Training, epoch 99/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7711 - loss: 0.2290
# Metric Test : 77.3113%
# Loss Test : 0.22688746
# ==================================================
# Training, epoch 100/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7651 - loss: 0.2349
# Metric Test : 83.1406%
# Loss Test : 0.16859353
# ==================================================
# Training, epoch 101/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7760 - loss: 0.2240
# Metric Test : 80.3842%
# Loss Test : 0.19615793
# ==================================================
# Training, epoch 102/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7792 - loss: 0.2208
# Metric Test : 82.0008%
# Loss Test : 0.17999232
# ==================================================
# Training, epoch 103/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7812 - loss: 0.2188
# Metric Test : 78.1032%
# Loss Test : 0.2189678
# ==================================================
# Training, epoch 104/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7796 - loss: 0.2204
# Metric Test : 82.6686%
# Loss Test : 0.17331362
# ==================================================
# Training, epoch 105/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7420 - loss: 0.2580
# Metric Test : 81.4221%
# Loss Test : 0.18577868
# ==================================================
# Training, epoch 106/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7651 - loss: 0.2348
# Metric Test : 82.9018%
# Loss Test : 0.17098206
# ==================================================
# Training, epoch 107/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7734 - loss: 0.2266
# Metric Test : 79.6734%
# Loss Test : 0.20326602
# ==================================================
# Training, epoch 108/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7694 - loss: 0.2305
# Metric Test : 81.1105%
# Loss Test : 0.1888951
# ==================================================
# Training, epoch 109/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7609 - loss: 0.2391
# Metric Test : 79.2439%
# Loss Test : 0.20756137
# ==================================================
# Training, epoch 110/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7740 - loss: 0.2260
# Metric Test : 81.5809%
# Loss Test : 0.18419123
# ==================================================
# Training, epoch 111/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7728 - loss: 0.2272
# Metric Test : 79.1636%
# Loss Test : 0.20836431
# ==================================================
# Training, epoch 112/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7832 - loss: 0.2168
# Metric Test : 79.9318%
# Loss Test : 0.20068228
# ==================================================
# Training, epoch 113/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7804 - loss: 0.2196
# Metric Test : 84.2913%
# Loss Test : 0.15708673
# ==================================================
# Training, epoch 114/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7937 - loss: 0.2063
# Metric Test : 80.8502%
# Loss Test : 0.1914978
# ==================================================
# Training, epoch 115/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7892 - loss: 0.2108
# Metric Test : 82.8201%
# Loss Test : 0.1717987
# ==================================================
# Training, epoch 116/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7839 - loss: 0.2161
# Metric Test : 82.8670%
# Loss Test : 0.17132986
# ==================================================
# Training, epoch 117/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8073 - loss: 0.1927
# Metric Test : 82.0118%
# Loss Test : 0.17988181
# ==================================================
# Training, epoch 118/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7853 - loss: 0.2147
# Metric Test : 81.5962%
# Loss Test : 0.18403822
# ==================================================
# Training, epoch 119/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.7679 - loss: 0.2320
# Metric Test : 81.3862%
# Loss Test : 0.18613845
# ==================================================
# Training, epoch 120/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7762 - loss: 0.2237
# Metric Test : 84.7748%
# Loss Test : 0.15225238
# ==================================================
# Training, epoch 121/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7818 - loss: 0.2182
# Metric Test : 81.7156%
# Loss Test : 0.18284357
# ==================================================
# Training, epoch 122/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8010 - loss: 0.1989
# Metric Test : 81.3035%
# Loss Test : 0.18696463
# ==================================================
# Training, epoch 123/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7926 - loss: 0.2074
# Metric Test : 84.3687%
# Loss Test : 0.15631306
# ==================================================
# Training, epoch 124/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7811 - loss: 0.2188
# Metric Test : 81.5584%
# Loss Test : 0.18441582
# ==================================================
# Training, epoch 125/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8033 - loss: 0.1967
# Metric Test : 80.8684%
# Loss Test : 0.19131577
# ==================================================
# Training, epoch 126/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7989 - loss: 0.2011
# Metric Test : 84.1955%
# Loss Test : 0.15804517
# ==================================================
# Training, epoch 127/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7981 - loss: 0.2019
# Metric Test : 83.8981%
# Loss Test : 0.16101909
# ==================================================
# Training, epoch 128/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7841 - loss: 0.2159
# Metric Test : 84.7694%
# Loss Test : 0.15230614
# ==================================================
# Training, epoch 129/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7890 - loss: 0.2110
# Metric Test : 76.7683%
# Loss Test : 0.23231739
# ==================================================
# Training, epoch 130/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8034 - loss: 0.1966
# Metric Test : 82.8940%
# Loss Test : 0.17106044
# ==================================================
# Training, epoch 131/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7881 - loss: 0.2119
# Metric Test : 82.6944%
# Loss Test : 0.17305624
# ==================================================
# Training, epoch 132/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7842 - loss: 0.2158
# Metric Test : 84.0675%
# Loss Test : 0.15932512
# ==================================================
# Training, epoch 133/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8098 - loss: 0.1902
# Metric Test : 83.5142%
# Loss Test : 0.16485757
# ==================================================
# Training, epoch 134/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8041 - loss: 0.1958
# Metric Test : 84.3917%
# Loss Test : 0.15608251
# ==================================================
# Training, epoch 135/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7840 - loss: 0.2160
# Metric Test : 79.4243%
# Loss Test : 0.20575702
# ==================================================
# Training, epoch 136/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.7934 - loss: 0.2066
# Metric Test : 82.6302%
# Loss Test : 0.17369819
# ==================================================
# Training, epoch 137/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8108 - loss: 0.1892
# Metric Test : 81.7292%
# Loss Test : 0.18270802
# ==================================================
# Training, epoch 138/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.7688 - loss: 0.2313
# Metric Test : 82.4479%
# Loss Test : 0.17552143
# ==================================================
# Training, epoch 139/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8069 - loss: 0.1932
# Metric Test : 82.8349%
# Loss Test : 0.171651
# ==================================================
# Training, epoch 140/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8140 - loss: 0.1860
# Metric Test : 81.1554%
# Loss Test : 0.18844575
# ==================================================
# Training, epoch 141/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7860 - loss: 0.2139
# Metric Test : 84.8591%
# Loss Test : 0.15140945
# ==================================================
# Training, epoch 142/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7979 - loss: 0.2021
# Metric Test : 83.3279%
# Loss Test : 0.16672057
# ==================================================
# Training, epoch 143/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7969 - loss: 0.2031
# Metric Test : 82.8389%
# Loss Test : 0.17161113
# ==================================================
# Training, epoch 144/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7898 - loss: 0.2102
# Metric Test : 83.7476%
# Loss Test : 0.16252363
# ==================================================
# Training, epoch 145/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8143 - loss: 0.1857
# Metric Test : 82.6888%
# Loss Test : 0.17311174
# ==================================================
# Training, epoch 146/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8057 - loss: 0.1943
# Metric Test : 86.2996%
# Loss Test : 0.13700444
# ==================================================
# Training, epoch 147/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8108 - loss: 0.1892
# Metric Test : 83.7030%
# Loss Test : 0.16296983
# ==================================================
# Training, epoch 148/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8263 - loss: 0.1737
# Metric Test : 83.8201%
# Loss Test : 0.16179872
# ==================================================
# Training, epoch 149/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8027 - loss: 0.1972
# Metric Test : 84.5677%
# Loss Test : 0.15432298
# ==================================================
# Training, epoch 150/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8124 - loss: 0.1876
# Metric Test : 83.8545%
# Loss Test : 0.16145515
# ==================================================
# Training, epoch 151/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8258 - loss: 0.1741
# Metric Test : 82.4255%
# Loss Test : 0.17574471
# ==================================================
# Training, epoch 152/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.7968 - loss: 0.2032
# Metric Test : 83.6315%
# Loss Test : 0.16368479
# ==================================================
# Training, epoch 153/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8129 - loss: 0.1871
# Metric Test : 84.5128%
# Loss Test : 0.15487182
# ==================================================
# Training, epoch 154/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8003 - loss: 0.1997
# Metric Test : 82.0925%
# Loss Test : 0.17907548
# ==================================================
# Training, epoch 155/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8148 - loss: 0.1852
# Metric Test : 81.9132%
# Loss Test : 0.18086827
# ==================================================
# Training, epoch 156/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8003 - loss: 0.1997
# Metric Test : 83.9374%
# Loss Test : 0.1606257
# ==================================================
# Training, epoch 157/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8186 - loss: 0.1814
# Metric Test : 81.7769%
# Loss Test : 0.18223113
# ==================================================
# Training, epoch 158/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8090 - loss: 0.1910
# Metric Test : 83.0262%
# Loss Test : 0.16973823
# ==================================================
# Training, epoch 159/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7939 - loss: 0.2061
# Metric Test : 82.0894%
# Loss Test : 0.17910588
# ==================================================
# Training, epoch 160/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8075 - loss: 0.1925
# Metric Test : 83.4548%
# Loss Test : 0.16545236
# ==================================================
# Training, epoch 161/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8152 - loss: 0.1848
# Metric Test : 83.1352%
# Loss Test : 0.1686477
# ==================================================
# Training, epoch 162/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8089 - loss: 0.1911
# Metric Test : 83.2084%
# Loss Test : 0.16791648
# ==================================================
# Training, epoch 163/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.7953 - loss: 0.2046
# Metric Test : 77.1081%
# Loss Test : 0.22891903
# ==================================================
# Training, epoch 164/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8191 - loss: 0.1809
# Metric Test : 84.6334%
# Loss Test : 0.15366608
# ==================================================
# Training, epoch 165/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.7956 - loss: 0.2044
# Metric Test : 83.2644%
# Loss Test : 0.1673562
# ==================================================
# Training, epoch 166/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8220 - loss: 0.1780
# Metric Test : 84.8779%
# Loss Test : 0.15122145
# ==================================================
# Training, epoch 167/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8249 - loss: 0.1751
# Metric Test : 82.3509%
# Loss Test : 0.17649072
# ==================================================
# Training, epoch 168/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8138 - loss: 0.1862
# Metric Test : 83.5473%
# Loss Test : 0.164527
# ==================================================
# Training, epoch 169/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - dice__coef: 0.8146 - loss: 0.1854
# Metric Test : 84.2957%
# Loss Test : 0.15704316
# ==================================================
# Training, epoch 170/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 220ms/step - dice__coef: 0.8376 - loss: 0.1624
# Metric Test : 83.0213%
# Loss Test : 0.16978651
# ==================================================
# Training, epoch 171/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8057 - loss: 0.1943
# Metric Test : 86.4926%
# Loss Test : 0.13507378
# ==================================================
# Training, epoch 172/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8283 - loss: 0.1717
# Metric Test : 78.3685%
# Loss Test : 0.21631491
# ==================================================
# Training, epoch 173/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8005 - loss: 0.1995
# Metric Test : 83.2913%
# Loss Test : 0.16708726
# ==================================================
# Training, epoch 174/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8258 - loss: 0.1742
# Metric Test : 83.6916%
# Loss Test : 0.16308427
# ==================================================
# Training, epoch 175/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8261 - loss: 0.1738
# Metric Test : 85.1324%
# Loss Test : 0.14867562
# ==================================================
# Training, epoch 176/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - dice__coef: 0.8168 - loss: 0.1832
# Metric Test : 85.4593%
# Loss Test : 0.14540702
# ==================================================
# Training, epoch 177/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8132 - loss: 0.1868
# Metric Test : 83.0689%
# Loss Test : 0.16931075
# ==================================================
# Training, epoch 178/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8160 - loss: 0.1841
# Metric Test : 86.3924%
# Loss Test : 0.13607591
# ==================================================
# Training, epoch 179/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8385 - loss: 0.1615
# Metric Test : 83.2222%
# Loss Test : 0.16777778
# ==================================================
# Training, epoch 180/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8296 - loss: 0.1704
# Metric Test : 84.5461%
# Loss Test : 0.15453911
# ==================================================
# Training, epoch 181/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8124 - loss: 0.1876
# Metric Test : 84.7255%
# Loss Test : 0.15274513
# ==================================================
# Training, epoch 182/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8285 - loss: 0.1715
# Metric Test : 86.2453%
# Loss Test : 0.13754731
# ==================================================
# Training, epoch 183/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8182 - loss: 0.1818
# Metric Test : 85.9679%
# Loss Test : 0.14032131
# ==================================================
# Training, epoch 184/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8199 - loss: 0.1801
# Metric Test : 85.7988%
# Loss Test : 0.14201176
# ==================================================
# Training, epoch 185/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8242 - loss: 0.1758
# Metric Test : 86.1718%
# Loss Test : 0.13828176
# ==================================================
# Training, epoch 186/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8137 - loss: 0.1862
# Metric Test : 81.8639%
# Loss Test : 0.1813615
# ==================================================
# Training, epoch 187/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8169 - loss: 0.1831
# Metric Test : 84.7363%
# Loss Test : 0.15263742
# ==================================================
# Training, epoch 188/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8241 - loss: 0.1760
# Metric Test : 83.1859%
# Loss Test : 0.16814065
# ==================================================
# Training, epoch 189/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8143 - loss: 0.1857
# Metric Test : 85.4198%
# Loss Test : 0.14580172
# ...
# Metric Test : 88.6801%
# Loss Test : 0.11319947
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 556/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8854 - loss: 0.1146
# Metric Test : 88.5263%
# Loss Test : 0.11473733
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 557/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8763 - loss: 0.1237
# Metric Test : 87.9417%
# Loss Test : 0.12058252
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 558/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8904 - loss: 0.1096
# Metric Test : 87.7823%
# Loss Test : 0.122177064
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 559/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8846 - loss: 0.1154
# Metric Test : 87.0403%
# Loss Test : 0.12959653
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 560/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8861 - loss: 0.1139
# Metric Test : 86.4714%
# Loss Test : 0.13528568
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 561/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8853 - loss: 0.1146
# Metric Test : 89.1592%
# Loss Test : 0.108407736
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 562/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8785 - loss: 0.1215
# Metric Test : 82.6135%
# Loss Test : 0.17386472
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 563/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8783 - loss: 0.1217
# Metric Test : 89.3861%
# Loss Test : 0.10613918
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 564/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8807 - loss: 0.1193
# Metric Test : 89.8699%
# Loss Test : 0.1013006
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 565/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.9025 - loss: 0.0975
# Metric Test : 89.3428%
# Loss Test : 0.10657185
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 566/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8896 - loss: 0.1104
# Metric Test : 88.9329%
# Loss Test : 0.11067122
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 567/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8764 - loss: 0.1236
# Metric Test : 88.5662%
# Loss Test : 0.11433828
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 568/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8911 - loss: 0.1089
# Metric Test : 89.3887%
# Loss Test : 0.10611296
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 569/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8899 - loss: 0.1101
# Metric Test : 89.5620%
# Loss Test : 0.10438031
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 570/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8804 - loss: 0.1196
# Metric Test : 88.6443%
# Loss Test : 0.11355692
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 571/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8857 - loss: 0.1143
# Metric Test : 89.0861%
# Loss Test : 0.10913926
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 572/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8646 - loss: 0.1354
# Metric Test : 89.4714%
# Loss Test : 0.10528618
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 573/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8852 - loss: 0.1148
# Metric Test : 84.1132%
# Loss Test : 0.1588682
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 574/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8664 - loss: 0.1336
# Metric Test : 89.0153%
# Loss Test : 0.10984653
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 575/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8873 - loss: 0.1127
# Metric Test : 88.5012%
# Loss Test : 0.11498803
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 576/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8834 - loss: 0.1166
# Metric Test : 89.3919%
# Loss Test : 0.10608131
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 577/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8747 - loss: 0.1253
# Metric Test : 88.7220%
# Loss Test : 0.11278027
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 578/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8882 - loss: 0.1118
# Metric Test : 88.3338%
# Loss Test : 0.116662145
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 579/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8948 - loss: 0.1051
# Metric Test : 89.5436%
# Loss Test : 0.10456443
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 580/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8899 - loss: 0.1101
# Metric Test : 89.1716%
# Loss Test : 0.10828364
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 581/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8833 - loss: 0.1168
# Metric Test : 89.2079%
# Loss Test : 0.107920766
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 582/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - dice__coef: 0.8871 - loss: 0.1129
# Metric Test : 89.2827%
# Loss Test : 0.10717344
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 583/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8751 - loss: 0.1249
# Metric Test : 88.5052%
# Loss Test : 0.11494768
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 584/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8882 - loss: 0.1118
# Metric Test : 87.7476%
# Loss Test : 0.122523904
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 585/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 226ms/step - dice__coef: 0.8782 - loss: 0.1218
# Metric Test : 88.2914%
# Loss Test : 0.11708605
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 586/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8978 - loss: 0.1022
# Metric Test : 89.2729%
# Loss Test : 0.107270956
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 587/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8816 - loss: 0.1184
# Metric Test : 88.0276%
# Loss Test : 0.119724214
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 588/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8782 - loss: 0.1218
# Metric Test : 88.9487%
# Loss Test : 0.110512614
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 589/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8939 - loss: 0.1061
# Metric Test : 89.0607%
# Loss Test : 0.10939276
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 590/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8908 - loss: 0.1092
# Metric Test : 86.7611%
# Loss Test : 0.13238853
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 591/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8976 - loss: 0.1024
# Metric Test : 89.9963%
# Loss Test : 0.100037456
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 592/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8838 - loss: 0.1162
# Metric Test : 88.3859%
# Loss Test : 0.11614066
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 593/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8795 - loss: 0.1205
# Metric Test : 89.6320%
# Loss Test : 0.103679776
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 594/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8810 - loss: 0.1190
# Metric Test : 89.7865%
# Loss Test : 0.102134585
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 595/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 226ms/step - dice__coef: 0.8821 - loss: 0.1179
# Metric Test : 89.5879%
# Loss Test : 0.10412073
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 596/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8857 - loss: 0.1143
# Metric Test : 89.7374%
# Loss Test : 0.10262644
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 597/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8768 - loss: 0.1232
# Metric Test : 88.7795%
# Loss Test : 0.11220497
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 598/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - dice__coef: 0.8850 - loss: 0.1150
# Metric Test : 89.4809%
# Loss Test : 0.10519117
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 599/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8904 - loss: 0.1096
# Metric Test : 89.1247%
# Loss Test : 0.10875332
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================
# Training, epoch 600/600
# ==================================================
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - dice__coef: 0.8920 - loss: 0.1080
# Metric Test : 88.5746%
# Loss Test : 0.11425406
# ==================================================
# Save model from epoch 478 with metric 90.6638%
# ==================================================

# %% [markdown]
# # **Phân đoạn ảnh dựa trên mô hình đã training :**

# %%
#Reload the best model :
path = '/kaggle/working/' + model_path

model = tf.keras.models.load_model(
    path, custom_objects={'Dice_Coef': Dice_Coef, 'Dice_Loss' : Dice_Loss}
)

# %%
print("Prediction")
print("=" *50)
y_pred = model.predict(x_test, batch_size=8, verbose=0)
y_pred_b = (y_pred >= 0.5).astype(np.float32)
# Out:
# Prediction
# ==================================================

# %% [markdown]
# **Hiển thị kết quả phân đoạn (Dice Coeficent, Jacard, Accuracy) :**

# %%
dice_scores = []
jaccard_scores = []
accuracy_scores = []
y_true = y_true_thr = y_test

for i in range(len(y_test)) :
    
    flattened_labels = K.flatten(y_true_thr[i])
    flattened_predictions = K.flatten(y_pred_b[i])
    
    #Tính Dice Coefficient và Jaccard Index :
    dice_scores.append(Dice_Coef(y_true[i], y_pred[i]))
    jaccard_scores.append(jaccard_score(flattened_labels, flattened_predictions))

    #Tính Accuracy :
    accuracy_scores.append(accuracy_score(flattened_labels, flattened_predictions))

#In ra kết quả :
print(f"Dice Coefficient Mean: {np.mean(dice_scores)*100}%")
print(f"Jaccard Index Mean: {np.mean(jaccard_scores)*100}%")
print(f"Accuracy Mean: {np.mean(accuracy_scores)*100}%")
# Out:
# Dice Coefficient Mean: 89.87911939620972%
# Jaccard Index Mean: 83.8160384787935%
# Accuracy Mean: 97.13339233398438%

# %% [markdown]
# **Trực quan hoá metric :**

# %%
#Tính means :
mean_dice = np.mean(dice_scores) * 100
mean_jaccard = np.mean(jaccard_scores) * 100
mean_accuracy = np.mean(accuracy_scores) * 100

#Dữ liệu trực quan :
metrics = ['Dice Coefficient', 'Jaccard Index', 'Accuracy']
values = [mean_dice, mean_jaccard, mean_accuracy]

#Tạo biểu đồ cột :
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=metrics, y=values, palette="viridis")

#Thêm giá trị của các metric lên cột :
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.3f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 10),
                textcoords = 'offset points')

#Thiết lập labels và title :
ax.set(ylim=(0, 100))
plt.ylabel('Score (%)')
plt.title('Average Metrics')

#Hiển thị biểu đồ :
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# # **Hiển thị ảnh đã phân đoạn :**

# %%
def Show_Images_Mask_Pred(x_test, y_true, binary_predictions, qual=10):
    top_qual = np.argsort(dice_scores)[-qual:]
    
    for i in top_qual :
        plt.figure(figsize=(15, 5))

        #Hệ số Dice Coef, Jaccard, Accuracy :
        print(f'Accuracy For Image {i}: {accuracy_scores[i]}')
        print(f'Dice Coefficent For Image {i}: {dice_scores[i]}')
        print(f'Jaccard For Image {i}: {jaccard_scores[i]}')

        plt.subplot(1, 4, 1)
        plt.imshow(x_test[i][...,::-1])
        plt.title('Ảnh Thật')
        plt.axis('off')  # Bỏ grid

        plt.subplot(1, 4, 2)
        plt.imshow(y_true[i], cmap='gray')
        plt.title('Mặt Nạ Thật')
        plt.axis('off')  # Bỏ grid

            
        plt.subplot(1, 4, 3)
        plt.imshow(y_pred[i], cmap='gray')
        plt.title('Dự Đoán Chưa Áp Ngưỡng')
        plt.axis('off')  # Bỏ grid

    
        plt.subplot(1, 4, 4)
        plt.imshow(y_pred_b[i], cmap='gray')
        plt.title('Dự Đoán Đã Áp Ngưỡng')
        plt.axis('off')  # Bỏ grid

        plt.show()
        print('='*80)

# %%
Show_Images_Mask_Pred(x_test , y_test, 
                      y_pred_b, 
                      qual = 10)
# Out:
# Accuracy For Image 33: 0.9945068359375
# Dice Coefficent For Image 33: 0.9851275682449341
# Jaccard For Image 33: 0.9708289441698403
# ================================================================================
# Accuracy For Image 147: 0.99456787109375
# Dice Coefficent For Image 147: 0.9853756427764893
# Jaccard For Image 147: 0.971178756476684
# ================================================================================
# Accuracy For Image 83: 0.997314453125
# Dice Coefficent For Image 83: 0.9865393042564392
# Jaccard For Image 83: 0.9735656353259237
# ================================================================================
# Accuracy For Image 60: 0.997650146484375
# Dice Coefficent For Image 60: 0.9866178631782532
# Jaccard For Image 60: 0.9736165838615727
# ================================================================================
# Accuracy For Image 117: 0.9961700439453125
# Dice Coefficent For Image 117: 0.9868684411048889
# Jaccard For Image 117: 0.9747103274559193
# ================================================================================
# Accuracy For Image 106: 0.9906005859375
# Dice Coefficent For Image 106: 0.9873573184013367
# Jaccard For Image 106: 0.9748786754210677
# ================================================================================
# Accuracy For Image 0: 0.9974212646484375
# Dice Coefficent For Image 0: 0.9885463118553162
# Jaccard For Image 0: 0.9773184807408402
# ================================================================================
# Accuracy For Image 97: 0.9906158447265625
# Dice Coefficent For Image 97: 0.9886497259140015
# Jaccard For Image 97: 0.9775490088708795
# ================================================================================
# Accuracy For Image 111: 0.9979248046875
# Dice Coefficent For Image 111: 0.9892829060554504
# Jaccard For Image 111: 0.9787930765632309
# ================================================================================
# Accuracy For Image 22: 0.9936981201171875
# Dice Coefficent For Image 22: 0.9955205321311951
# Jaccard For Image 22: 0.9910876132930514
# ================================================================================
